# %%
from world_maps.maze import Maze_World
from agent.agent_L1 import Agent
from render.render_L1 import display

# %%
world = Maze_World(name = "maze")
world.generate_maze(1,1)
agent1 =  Agent(env = world)

# %%
display(world, agent1.pos)
